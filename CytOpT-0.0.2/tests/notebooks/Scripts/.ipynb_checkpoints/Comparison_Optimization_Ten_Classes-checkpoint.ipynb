# %% [markdown]
# ### Comparison between the two optimization methods proposed  in the article: The descent-ascent procedure and the minmax swapping procedure.

# %% [markdown]
# ##### Import modules and functions

# %%
import pandas as pd
import numpy as np
import time
from CytOpT import CytOpt
from CytOpT import CytOpt_plot

# %% [markdown]
# ##### Import data

# %%
#Source Data

Stanford1A_values = pd.read_csv('../Data/W2_1_values.csv',
                                 usecols = np.arange(1,8))
Stanford1A_clust = pd.read_csv('../Data/W2_1_clust.csv',
                                usecols = [1])

#Target Data

Stanford3A_values = pd.read_csv('../Data/W2_7_values.csv',
                                 usecols = np.arange(1,8))
Stanford3A_clust = pd.read_csv('../Data/W2_7_clust.csv',
                                usecols = [1])

# %% [markdown]
# We are in the frame work where our cytometry data are divided into 10 classes and the 7 markers available are used to estimate the class proportions in the target data set.

# %% [markdown]
# ##### Preprocessing of the data sets

# %%
X_source = np.asarray(Stanford1A_values)
X_target = np.asarray(Stanford3A_values)

Lab_source = np.asarray(Stanford1A_clust['x'])
Lab_target = np.asarray(Stanford3A_clust['x'])

# %% [markdown]
# #####  Computation of the benchmark proportions $p$ in the target data set

# %%
h_target = np.zeros(10)
for k in range(10):
    h_target[k] = np.sum(Lab_target == k+1)/len(Lab_target)

print(h_target)
# Out:
# [0.017004   0.12873617 0.048482   0.05748411 0.00909037 0.00232408
#  0.33146034 0.28171334 0.10208284 0.02162273]

# %% [markdown]
# ### ${\tt CytOpt}$ to compute an estimate $\hat{p}$ of the class proportions.

# %% [markdown]
# ##### Estimation with the minmax swapping procedure

# %% [markdown]
# Setting of the parameters

# %%
lbd = 0.0001
eps_one = 0.0001
n_iter = 10000
step_size = 5
power = 0.99

# %%
t0 = time.time()

res_one = CytOpt.CytOpT(X_source, X_target, Lab_source, theta_true=h_target,
                             method="minmax",lbd=lbd,eps=eps_one,n_iter=n_iter,step=step_size,power=power)
elapsed_time = time.time() - t0
print('Elapsed time : ',elapsed_time/60, 'Mins')
# Out:
# Done ( 33.104660749435425 s)
#
# Elapsed time :  0.551974872748057 Mins

# %%
res_one
# Out:
# {'proportions':    Gold_standard    minmax
#  0       0.017004  0.044813
#  1       0.128736  0.096391
#  2       0.048482  0.036761
#  3       0.057484  0.075235
#  4       0.009090  0.005700
#  5       0.002324  0.008818
#  6       0.331460  0.342283
#  7       0.281713  0.210256
#  8       0.102083  0.172024
#  9       0.021623  0.007718,
#  'monitoring':         minmax
#  0     0.000000
#  1     0.905097
#  2     2.775436
#  3     0.253816
#  4     0.368968
#  ...        ...
#  9995  0.065758
#  9996  0.065717
#  9997  0.065911
#  9998  0.066106
#  9999  0.066009
#
#  [10000 rows x 1 columns]}

# %%
Kull_Monitoring  = res_one['monitoring']

# %% [markdown]
# ##### Estimation with the descent-ascent procedure

# %%
n_it_grad = 10000
n_it_sto = 10
pas_grad = 10
eps=0.0005

# %%
t0 = time.time()

res_two = CytOpt.CytOpT(X_source, X_target, Lab_source, theta_true=h_target,
                             method="desasc",n_it_grad=n_it_grad,n_it_sto=n_it_sto,step_grad=pas_grad,eps=eps)
elapsed_time = time.time() - t0
print('Elapsed time : ',elapsed_time/60, 'Mins')
# Out:
#  Epsilon:  0.0005
# Iteration  0
# Current h_hat
# [0.10094388 0.10077563 0.10156384 0.10070132 0.09948529 0.09550914
#  0.10101549 0.10141827 0.1007707  0.09781644]
# Iteration  100
# Current h_hat
# [0.10822667 0.11245975 0.09053832 0.12969964 0.07220772 0.0301904
#  0.13169388 0.12777836 0.1311329  0.06607236]
# Iteration  200
# Current h_hat
# [0.10802635 0.10869787 0.07438511 0.13427115 0.05480109 0.01734352
#  0.16182146 0.14095091 0.15037349 0.04932905]
# Iteration  300
# Current h_hat
# [0.10602265 0.10765578 0.0649183  0.10749714 0.04572777 0.01565904
#  0.19040174 0.15205054 0.16081747 0.04924957]
# Iteration  400
# Current h_hat
# [0.10074518 0.11041019 0.05974806 0.10405636 0.03981944 0.01327046
#  0.20751955 0.17199597 0.14782734 0.04460745]
# Iteration  500
# Current h_hat
# [0.10039957 0.10519468 0.05871545 0.09446384 0.03310306 0.01175475
#  0.23167272 0.1820288  0.14316331 0.03950383]
# Iteration  600
# Current h_hat
# [0.09065011 0.09724459 0.05401953 0.08578143 0.02722252 0.01060288
#  0.29163636 0.17202843 0.13545358 0.03536056]
# Iteration  700
# Current h_hat
# [0.08020078 0.09532375 0.04942994 0.08525251 0.02587861 0.01116092
#  0.33650454 0.15248701 0.13205092 0.03171104]
# Iteration  800
# Current h_hat
# [0.07401614 0.08986481 0.04821339 0.07898717 0.02461854 0.01044631
#  0.37435369 0.15111773 0.1188012  0.02958102]
# Iteration  900
# Current h_hat
# [0.07565933 0.08815528 0.04789696 0.07539606 0.02294323 0.01000395
#  0.37511644 0.15938129 0.11560522 0.02984224]
# Iteration  1000
# Current h_hat
# [0.07567191 0.09287431 0.04812316 0.07643368 0.02141508 0.00919393
#  0.34306912 0.17021716 0.13505554 0.02794612]
# Iteration  1100
# Current h_hat
# [0.06725313 0.09494521 0.04782484 0.07251783 0.02120069 0.00865015
#  0.35362849 0.17377081 0.13442177 0.02578708]
# Iteration  1200
# Current h_hat
# [0.06468303 0.09115687 0.04786785 0.07233603 0.02058917 0.00857553
#  0.33420742 0.18899721 0.14537804 0.02620885]
# Iteration  1300
# Current h_hat
# [0.06389386 0.0924835  0.04770673 0.07209933 0.02037063 0.00805578
#  0.33946494 0.19824294 0.13264208 0.02504022]
# Iteration  1400
# Current h_hat
# [0.06096058 0.09088662 0.04418418 0.07373125 0.01955652 0.00745982
#  0.34180938 0.19694601 0.14113677 0.02332887]
# Iteration  1500
# Current h_hat
# [0.06104363 0.09538416 0.04149632 0.07303863 0.01835068 0.00692217
#  0.33466219 0.18601745 0.16014891 0.02293585]
# Iteration  1600
# Current h_hat
# [0.06110114 0.09746003 0.03915404 0.06634252 0.01840449 0.00657259
#  0.32726313 0.1988023  0.16296824 0.02193153]
# Iteration  1700
# Current h_hat
# [0.0613179  0.10287026 0.03883271 0.06827606 0.01832411 0.00633283
#  0.30481938 0.20635283 0.17232644 0.02054748]
# Iteration  1800
# Current h_hat
# [0.0594341  0.10106872 0.03896171 0.06967893 0.01852433 0.00622658
#  0.28160081 0.19992186 0.20445615 0.02012681]
# Iteration  1900
# Current h_hat
# [0.05738786 0.09871455 0.0365171  0.06437111 0.01810379 0.00597411
#  0.32396821 0.18961496 0.18634003 0.0190083 ]
# Iteration  2000
# Current h_hat
# [0.05638021 0.08766095 0.03625437 0.05874962 0.01734325 0.00572932
#  0.34085559 0.18450669 0.19512896 0.01739103]
# Iteration  2100
# Current h_hat
# [0.05580994 0.09240921 0.0347234  0.05693253 0.01642003 0.00542123
#  0.37845564 0.16652014 0.1769869  0.01632098]
# Iteration  2200
# Current h_hat
# [0.05865071 0.09086687 0.03634268 0.05956889 0.01620641 0.00529002
#  0.37499369 0.17301645 0.16835827 0.016706  ]
# Iteration  2300
# Current h_hat
# [0.05678804 0.09294495 0.03470645 0.06048271 0.01583164 0.00528566
#  0.34122764 0.2193949  0.15721725 0.01612075]
# Iteration  2400
# Current h_hat
# [0.05611772 0.09653216 0.03405128 0.05599038 0.01532772 0.00510594
#  0.34991677 0.21963364 0.15188902 0.01543539]
# Iteration  2500
# Current h_hat
# [0.05703184 0.09369759 0.03414365 0.06054684 0.01560191 0.0051955
#  0.34217892 0.21987984 0.15588615 0.01583775]
# Iteration  2600
# Current h_hat
# [0.05758665 0.08854324 0.0374946  0.06683476 0.01642077 0.005321
#  0.35328356 0.21160221 0.14615152 0.0167617 ]
# Iteration  2700
# Current h_hat
# [0.05800848 0.08435824 0.03396736 0.06658258 0.01501306 0.00501698
#  0.35666247 0.21110853 0.15313177 0.01615053]
# Iteration  2800
# Current h_hat
# [0.05874487 0.08424257 0.03289704 0.07205943 0.01478475 0.0050187
#  0.33439965 0.23529963 0.14645641 0.01609695]
# Iteration  2900
# Current h_hat
# [0.05958449 0.08768894 0.03418651 0.07005987 0.01441509 0.00504775
#  0.3249144  0.21611681 0.17138257 0.01660357]
# Iteration  3000
# Current h_hat
# [0.05726575 0.08533538 0.03274436 0.06786826 0.0142554  0.00482592
#  0.34697878 0.22096509 0.15332695 0.01643411]
# Iteration  3100
# Current h_hat
# [0.06221858 0.08520734 0.03174869 0.07111576 0.01425474 0.00489128
#  0.32563706 0.22707584 0.16163747 0.01621324]
# Iteration  3200
# Current h_hat
# [0.05962527 0.08633738 0.03099545 0.06927304 0.01402492 0.00472058
#  0.34114404 0.23565012 0.14266588 0.01556331]
# Iteration  3300
# Current h_hat
# [0.05868551 0.08754855 0.03126018 0.06755192 0.01409003 0.00456422
#  0.35948485 0.22761501 0.13402305 0.01517668]
# Iteration  3400
# Current h_hat
# [0.05567148 0.07927544 0.03048811 0.06323215 0.01382178 0.00458769
#  0.37766697 0.20715377 0.15298778 0.01511483]
# Iteration  3500
# Current h_hat
# [0.05475196 0.07692149 0.03077821 0.05984626 0.01358722 0.00463924
#  0.38663638 0.20881485 0.14980239 0.014222  ]
# Iteration  3600
# Current h_hat
# [0.05914396 0.08595068 0.03337437 0.06484029 0.01441213 0.00492712
#  0.3398969  0.21970209 0.16240498 0.01534748]
# Iteration  3700
# Current h_hat
# [0.0570796  0.07885588 0.03226927 0.06068719 0.01385506 0.0047616
#  0.39133826 0.19553878 0.15094399 0.01467037]
# Iteration  3800
# Current h_hat
# [0.06008693 0.08316355 0.03371857 0.0602199  0.01418872 0.00478369
#  0.35779145 0.20789371 0.16255693 0.01559655]
# Iteration  3900
# Current h_hat
# [0.06271286 0.08930672 0.03646642 0.06353805 0.01435773 0.00493647
#  0.36249212 0.20649088 0.14366967 0.01602909]
# Iteration  4000
# Current h_hat
# [0.06444811 0.09419939 0.03764029 0.06494791 0.01443906 0.00490559
#  0.35320329 0.20346337 0.14539184 0.01736114]
# Iteration  4100
# Current h_hat
# [0.06461974 0.10009729 0.03754101 0.06994304 0.01465693 0.00481621
#  0.35816266 0.18829128 0.14452585 0.017346  ]
# Iteration  4200
# Current h_hat
# [0.06914892 0.10483225 0.03979032 0.07425149 0.01473444 0.00499389
#  0.30317588 0.20520436 0.16610865 0.0177598 ]
# Iteration  4300
# Current h_hat
# [0.06725547 0.10483732 0.03816465 0.06820532 0.01419571 0.00480559
#  0.33474452 0.2162893  0.13440199 0.01710013]
# Iteration  4400
# Current h_hat
# [0.06572414 0.10535881 0.0371254  0.068586   0.01462644 0.00488753
#  0.33200572 0.21830712 0.13593396 0.01744488]
# Iteration  4500
# Current h_hat
# [0.06680867 0.11181186 0.03818248 0.07359201 0.014741   0.0048795
#  0.30796686 0.22798066 0.13644193 0.01759502]
# Iteration  4600
# Current h_hat
# [0.06588304 0.11448064 0.03783326 0.07618563 0.01517868 0.00495253
#  0.31947502 0.23354207 0.11434282 0.01812631]
# Iteration  4700
# Current h_hat
# [0.06193671 0.09826304 0.03533883 0.07391432 0.01484901 0.00471832
#  0.33838537 0.24365932 0.11095921 0.01797588]
# Iteration  4800
# Current h_hat
# [0.06157919 0.09244526 0.03437739 0.07087153 0.01447906 0.0047258
#  0.35907046 0.23301644 0.11207715 0.01735774]
# Iteration  4900
# Current h_hat
# [0.06149899 0.08934835 0.03319012 0.07097255 0.01431366 0.00475649
#  0.34477163 0.23995468 0.12392531 0.01726821]
# Iteration  5000
# Current h_hat
# [0.06179135 0.09336521 0.03296219 0.07319289 0.01390188 0.00486856
#  0.34656316 0.23078679 0.12552311 0.01704486]
# Iteration  5100
# Current h_hat
# [0.06129718 0.10221962 0.03187787 0.071      0.0135252  0.00486939
#  0.35649988 0.2232153  0.1177751  0.01772048]
# Iteration  5200
# Current h_hat
# [0.06312166 0.10474049 0.03219064 0.06580071 0.0135936  0.00494649
#  0.35511452 0.21264807 0.13047334 0.01737047]
# Iteration  5300
# Current h_hat
# [0.06464835 0.11081231 0.03214085 0.06771937 0.01404587 0.00493011
#  0.35097251 0.19092218 0.14566268 0.01814576]
# Iteration  5400
# Current h_hat
# [0.0644883  0.10522626 0.03300006 0.07224415 0.0144258  0.00516718
#  0.31984151 0.20553854 0.16248546 0.01758275]
# Iteration  5500
# Current h_hat
# [0.06319653 0.10520526 0.03350243 0.0681325  0.01460727 0.00504185
#  0.33397661 0.19672828 0.16209948 0.01750979]
# Iteration  5600
# Current h_hat
# [0.06384142 0.10931098 0.03389485 0.06931145 0.01444852 0.00507427
#  0.33455768 0.18302678 0.1688372  0.01769686]
# Iteration  5700
# Current h_hat
# [0.06234682 0.12001041 0.03440282 0.06839139 0.01383507 0.00491477
#  0.32076571 0.19972103 0.15909438 0.0165176 ]
# Iteration  5800
# Current h_hat
# [0.05938948 0.11204023 0.03522807 0.06774098 0.01386039 0.00474213
#  0.34115778 0.20862997 0.14128315 0.01592782]
# Iteration  5900
# Current h_hat
# [0.05803836 0.10663166 0.03424208 0.06732023 0.01342134 0.00472943
#  0.34110915 0.20643854 0.15222865 0.01584056]
# Iteration  6000
# Current h_hat
# [0.05689476 0.10753134 0.0344008  0.06753625 0.01308747 0.00481353
#  0.33490493 0.21230018 0.15307403 0.01545671]
# Iteration  6100
# Current h_hat
# [0.05937253 0.11818146 0.03613647 0.0659821  0.01312615 0.00500463
#  0.30213806 0.24735605 0.13707978 0.01562278]
# Iteration  6200
# Current h_hat
# [0.05989517 0.12029426 0.0355147  0.06755343 0.0132993  0.00491415
#  0.29405698 0.23792022 0.15042115 0.01613064]
# Iteration  6300
# Current h_hat
# [0.06101968 0.1153727  0.03690671 0.0701864  0.01310717 0.00479448
#  0.33381424 0.21974188 0.12871562 0.01634113]
# Iteration  6400
# Current h_hat
# [0.05975998 0.10823573 0.03666373 0.06906282 0.01281521 0.00458968
#  0.32804434 0.22876489 0.13650848 0.01555515]
# Iteration  6500
# Current h_hat
# [0.05963214 0.09849554 0.03617402 0.0676693  0.01282753 0.00464547
#  0.32857691 0.23013434 0.14621412 0.01563064]
# Iteration  6600
# Current h_hat
# [0.05834924 0.09440625 0.03434349 0.06485602 0.01240983 0.00460028
#  0.36073943 0.20285359 0.15181304 0.01562882]
# Iteration  6700
# Current h_hat
# [0.05880197 0.10084422 0.03415889 0.06634754 0.01236773 0.00460509
#  0.3742827  0.19179991 0.1408898  0.01590215]
# Iteration  6800
# Current h_hat
# [0.05912841 0.10443196 0.03447828 0.07564278 0.0126459  0.00472992
#  0.33299296 0.18283406 0.17684521 0.01627054]
# Iteration  6900
# Current h_hat
# [0.05878852 0.10334632 0.03311958 0.07264777 0.01194822 0.00457927
#  0.36745652 0.16777399 0.16468789 0.01565193]
# Iteration  7000
# Current h_hat
# [0.05886051 0.10153454 0.03189837 0.07459482 0.0118925  0.00457798
#  0.36187457 0.17548668 0.16390603 0.015374  ]
# Iteration  7100
# Current h_hat
# [0.06115735 0.10123631 0.03226471 0.07529867 0.01226874 0.00476074
#  0.35316492 0.18992946 0.15405366 0.01586543]
# Iteration  7200
# Current h_hat
# [0.06121355 0.0982014  0.03248015 0.08080294 0.01213858 0.00464265
#  0.35274097 0.19305452 0.14938418 0.01534106]
# Iteration  7300
# Current h_hat
# [0.05712867 0.09563294 0.03246695 0.07533965 0.01257319 0.0045661
#  0.32296486 0.20983431 0.17410045 0.01539289]
# Iteration  7400
# Current h_hat
# [0.05392157 0.09258408 0.03299932 0.07682932 0.01204957 0.00444021
#  0.33153526 0.22407298 0.1564513  0.01511639]
# Iteration  7500
# Current h_hat
# [0.05198293 0.0904095  0.03249201 0.07396081 0.01181513 0.00438053
#  0.34052609 0.24258035 0.13759133 0.01426132]
# Iteration  7600
# Current h_hat
# [0.05023831 0.08627816 0.03095261 0.07065148 0.01181546 0.00425403
#  0.33073924 0.26050133 0.14039636 0.01417303]
# Iteration  7700
# Current h_hat
# [0.05029097 0.08861575 0.03200916 0.06808501 0.01156742 0.00423567
#  0.34732313 0.25500517 0.12887149 0.01399623]
# Iteration  7800
# Current h_hat
# [0.05271238 0.09472478 0.03292521 0.07037296 0.01185937 0.00437264
#  0.32662887 0.26449977 0.12783858 0.01406543]
# Iteration  7900
# Current h_hat
# [0.05207512 0.09228062 0.0334069  0.06716371 0.01174145 0.00439741
#  0.32143335 0.25944352 0.14391254 0.01414536]
# Iteration  8000
# Current h_hat
# [0.05180823 0.09197448 0.0316066  0.06770651 0.0116599  0.00422981
#  0.35303083 0.23565642 0.13798371 0.01434352]
# Iteration  8100
# Current h_hat
# [0.05295168 0.09588238 0.03286329 0.07241386 0.0119144  0.00433097
#  0.30857365 0.25299856 0.1530296  0.01504161]
# Iteration  8200
# Current h_hat
# [0.04969478 0.08910757 0.0300725  0.07454271 0.01138235 0.00399538
#  0.36879414 0.2152827  0.14315078 0.01397709]
# Iteration  8300
# Current h_hat
# [0.049284   0.08689849 0.02991555 0.06684969 0.01101709 0.00399261
#  0.40234832 0.19502902 0.14083897 0.01382625]
# Iteration  8400
# Current h_hat
# [0.05035775 0.09236194 0.0312985  0.06868327 0.01139191 0.00411315
#  0.37080491 0.21068395 0.14586128 0.01444334]
# Iteration  8500
# Current h_hat
# [0.05100095 0.09239569 0.03213093 0.0692585  0.01144534 0.00412475
#  0.35492031 0.23028587 0.14000742 0.01443025]
# Iteration  8600
# Current h_hat
# [0.04870201 0.09119342 0.03176515 0.06841739 0.01112235 0.00390855
#  0.37996182 0.21908104 0.13133494 0.01451332]
# Iteration  8700
# Current h_hat
# [0.04767222 0.09434509 0.03144692 0.06150587 0.01153959 0.00382508
#  0.37195355 0.22192121 0.1414964  0.01429407]
# Iteration  8800
# Current h_hat
# [0.04697764 0.0931588  0.03267582 0.0599602  0.01153563 0.00376728
#  0.35319074 0.20953889 0.17464091 0.01455409]
# Iteration  8900
# Current h_hat
# [0.04759318 0.09155815 0.03190233 0.06498945 0.01122739 0.00368038
#  0.37415643 0.21208567 0.1480095  0.01479751]
# Iteration  9000
# Current h_hat
# [0.04770442 0.09269455 0.03440338 0.06668192 0.01154397 0.00379898
#  0.3298776  0.22255597 0.17590365 0.01483556]
# Iteration  9100
# Current h_hat
# [0.05123083 0.09513609 0.03458901 0.07180328 0.01145285 0.00384594
#  0.29305509 0.25864451 0.16516897 0.01507342]
# Iteration  9200
# Current h_hat
# [0.0519798  0.09249308 0.03406493 0.07353912 0.0117945  0.0038077
#  0.30209152 0.25942052 0.15596265 0.01484618]
# Iteration  9300
# Current h_hat
# [0.04870296 0.0890574  0.0336605  0.06952265 0.01183749 0.00372368
#  0.30115086 0.26194226 0.16523234 0.01516987]
# Iteration  9400
# Current h_hat
# [0.0481156  0.08699584 0.03264593 0.06846702 0.01196807 0.00370644
#  0.32362788 0.23661504 0.17315086 0.01470733]
# Iteration  9500
# Current h_hat
# [0.04808258 0.08698478 0.03337497 0.06925667 0.01194787 0.00371567
#  0.3239137  0.25482811 0.15315727 0.01473838]
# Iteration  9600
# Current h_hat
# [0.04623057 0.08572334 0.03203095 0.06476206 0.0114711  0.00364217
#  0.33850217 0.2616445  0.14092554 0.01506759]
# Iteration  9700
# Current h_hat
# [0.04552647 0.08635388 0.03029767 0.06274921 0.01123702 0.00363202
#  0.35707941 0.23783771 0.15108245 0.01420417]
# Iteration  9800
# Current h_hat
# [0.04534608 0.08834543 0.0314161  0.06380327 0.0112477  0.00361591
#  0.35304716 0.24808317 0.14025093 0.01484425]
# Iteration  9900
# Current h_hat
# [0.04510468 0.09231781 0.03133433 0.0651413  0.01100091 0.00351857
#  0.34741184 0.25263113 0.13730709 0.01423236]
# Done ( 930.9639661312103 s)
#
# Elapsed time :  15.516315948963165 Mins

# %%
proportions = pd.concat([res_one['proportions'], res_two['proportions']], axis=1)
proportions
# Out:
#    Gold_standard    minmax  Gold_standard    desasc
# 0       0.017004  0.044813       0.017004  0.046397
# 1       0.128736  0.096391       0.128736  0.092152
# 2       0.048482  0.036761       0.048482  0.035303
# 3       0.057484  0.075235       0.057484  0.068008
# 4       0.009090  0.005700       0.009090  0.011481
# 5       0.002324  0.008818       0.002324  0.003598
# 6       0.331460  0.342283       0.331460  0.322669
# 7       0.281713  0.210256       0.281713  0.241191
# 8       0.102083  0.172024       0.102083  0.163836
# 9       0.021623  0.007718       0.021623  0.015365

# %%
monitoring = pd.concat([res_one['monitoring'], res_two['monitoring']], axis=1)
monitoring
# Out:
#         minmax    desasc
# 0     0.000000  0.802323
# 1     0.905097  0.771524
# 2     2.775436  0.760068
# 3     0.253816  0.749012
# 4     0.368968  0.745527
# ...        ...       ...
# 9995  0.065758  0.046895
# 9996  0.065717  0.046594
# 9997  0.065911  0.045612
# 9998  0.066106  0.045544
# 9999  0.066009  0.046379
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### Results of the two optimization procedures

# %% [markdown]
# We display the evolution of the Kullback-Leibler divergence between $\hat{p}$ and $p$, along the iterations of the two minimization procedures.

# %%
CytOpt_plot.bar_plot(proportions)
CytOpt_plot.KL_plot(monitoring, n_0=10, n_stop=8000)
